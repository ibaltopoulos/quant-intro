# %%
import datetime as dt
import pandas as pd
import pandas_datareader.data as web
from zipline.api import order, record, symbol
from zipline.algorithm import TradingAlgorithm
from zipline.utils.factory import load_bars_from_yahoo
from zipline.data.bundles import register, yahoo_equities

def initialize(context):
   pass

#order(symbol('AAPL'), 10)
def handle_data(context, data):
    order(symbol('AAPL'), 10)  
    record(AAPL=data.current(symbol('AAPL'), 'price'))

algo_obj = TradingAlgorithm(initialize=initialize, handle_data=handle_data)


start = dt.datetime(2000, 1, 1)
end = dt.datetime(2016, 12, 31)

#data = web.DataReader("AAPL", "yahoo", start, end)
data = load_bars_from_yahoo(stocks=["AAPL"], start=start, end=end)

# these are the tickers you would like data for
equities = {
    'AAPL',
    'MSFT',
    'GOOG',
}
register(
    'my-yahoo-equities-bundle',  # name this whatever you like
    yahoo_equities(equities),
)

perf_manual = algo_obj.run(data)

#perf_manual.summary()
# Out:
# C:\ProgramData\Anaconda3\envs\py34\lib\site-packages\ipykernel\__main__.py:24: DeprecationWarning: load_bars_from_yahoo is deprecated, please register a yahoo_equities data bundle instead
# C:\ProgramData\Anaconda3\envs\py34\lib\site-packages\zipline\assets\asset_writer.py:192: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   row = group.sort('end_date').iloc[-1]
# C:\ProgramData\Anaconda3\envs\py34\lib\site-packages\pandas\tseries\index.py:755: PerformanceWarning: Non-vectorized DateOffset being applied to Series or DatetimeIndex
#   PerformanceWarning)

# %%
perf_manual.
# Out:
#                          AAPL  algo_volatility  algorithm_period_return  \
# 2000-01-03 21:00:00  3.625643              NaN                 0.000000
# 2000-01-04 21:00:00  3.319964         0.000112                -0.000010
# 2000-01-05 21:00:00  3.368548         0.000079                -0.000015
# 2000-01-06 21:00:00  3.077039         0.000506                -0.000083
# 2000-01-07 21:00:00  3.222794         0.000585                -0.000050
#
#                         alpha  benchmark_period_return  benchmark_volatility  \
# 2000-01-03 21:00:00       NaN                -0.009549                   NaN
# 2000-01-04 21:00:00  0.000836                -0.047528              0.323229
# 2000-01-05 21:00:00 -0.000637                -0.045697              0.329321
# 2000-01-06 21:00:00 -0.006945                -0.044785              0.298325
# 2000-01-07 21:00:00 -0.002084                -0.018908              0.375301
#
#                          beta  capital_used   ending_cash  ending_exposure  \
# 2000-01-03 21:00:00       NaN       0.00000  100000.00000          0.00000
# 2000-01-04 21:00:00  0.000347     -34.19964   99965.80036         33.19964
# 2000-01-05 21:00:00  0.000164     -34.68548   99931.11488         67.37096
# 2000-01-06 21:00:00 -0.000595     -31.77039   99899.34449         92.31117
# 2000-01-07 21:00:00  0.000467     -33.22794   99866.11655        128.91176
#
#                               ...            short_exposure  short_value  \
# 2000-01-03 21:00:00           ...                         0            0
# 2000-01-04 21:00:00           ...                         0            0
# 2000-01-05 21:00:00           ...                         0            0
# 2000-01-06 21:00:00           ...                         0            0
# 2000-01-07 21:00:00           ...                         0            0
#
#                      shorts_count    sortino  starting_cash  \
# 2000-01-03 21:00:00             0        NaN   100000.00000
# 2000-01-04 21:00:00             0 -11.224972   100000.00000
# 2000-01-05 21:00:00             0 -12.341744    99965.80036
# 2000-01-06 21:00:00             0  -9.568029    99931.11488
# 2000-01-07 21:00:00             0  -5.098692    99899.34449
#
#                      starting_exposure  starting_value  trading_days  \
# 2000-01-03 21:00:00            0.00000         0.00000             1
# 2000-01-04 21:00:00            0.00000         0.00000             2
# 2000-01-05 21:00:00           33.19964        33.19964             3
# 2000-01-06 21:00:00           67.37096        67.37096             4
# 2000-01-07 21:00:00           92.31117        92.31117             5
#
#                                                           transactions  \
# 2000-01-03 21:00:00                                                 []
# 2000-01-04 21:00:00  [{'sid': Equity(0 [AAPL]), 'amount': 10, 'comm...
# 2000-01-05 21:00:00  [{'sid': Equity(0 [AAPL]), 'amount': 10, 'comm...
# 2000-01-06 21:00:00  [{'sid': Equity(0 [AAPL]), 'amount': 10, 'comm...
# 2000-01-07 21:00:00  [{'sid': Equity(0 [AAPL]), 'amount': 10, 'comm...
#
#                      treasury_period_return
# 2000-01-03 21:00:00                  0.0658
# 2000-01-04 21:00:00                  0.0649
# 2000-01-05 21:00:00                  0.0662
# 2000-01-06 21:00:00                  0.0657
# 2000-01-07 21:00:00                  0.0652
#
# [5 rows x 39 columns]
